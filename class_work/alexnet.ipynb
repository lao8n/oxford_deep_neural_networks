# %%
import torch
import torch.nn as nn
from torchsummary import summary

class CustomAlexNet(nn.Module):
    def __init__(self, num_classes=1000):
        super(CustomAlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=0),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 256, kernel_size=5, stride=1, padding=2),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(14 * 14 * 512, 4096),
            nn.Linear(4096, 4096),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        print(x.shape)
        x = x.view(x.size(0), -1)
        print(x.shape)
        x = self.classifier(x)
        return x

# Instantiate the network
net = CustomAlexNet(num_classes=1000)
print(net)
summary(net, (3, 256, 256))
# Out:
# CustomAlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2))
#     (1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(64, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=100352, out_features=4096, bias=True)
#     (1): Linear(in_features=4096, out_features=4096, bias=True)
#     (2): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )
# torch.Size([2, 512, 14, 14])
# torch.Size([2, 100352])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 125, 125]           9,472
#          MaxPool2d-2           [-1, 64, 62, 62]               0
#             Conv2d-3          [-1, 256, 62, 62]         409,856
#          MaxPool2d-4          [-1, 256, 30, 30]               0
#             Conv2d-5          [-1, 512, 30, 30]       1,180,160
#             Conv2d-6          [-1, 512, 30, 30]       2,359,808
#             Conv2d-7          [-1, 512, 30, 30]       2,359,808
#          MaxPool2d-8          [-1, 512, 14, 14]               0
#             Linear-9                 [-1, 4096]     411,045,888
#            Linear-10                 [-1, 4096]      16,781,312
#            Linear-11                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 438,243,304
# Trainable params: 438,243,304
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 30.15
# Params size (MB): 1671.77
# Estimated Total Size (MB): 1702.67
# ----------------------------------------------------------------
